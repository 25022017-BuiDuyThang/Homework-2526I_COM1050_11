# %%
#1
import math
pi = 3.14
def Rounding(x):
    return (f"{x:.2f}")
class Cylinder: 
    def __init__(self, radius, height): 
        self._radius = radius
        self._height = height
    def area(self): 
        return 2 *pi * self._radius * self._height
    def volume(self): 
        r = self._radius
        return pi * r * r *self._height

a = Cylinder(3,4)
print(Rounding(a.area())) 
print(" ")
print(Rounding(a.volume()))

# %%
#2
class Date:

# %%
#3
import math
def Rounding(x):
    return (f"{x:.2f}")
class coordinate: 
    def __init__(self, x, y): 
        self.x = x
        self.y = y

    def check(self): 
        x1 = self.x
        y1 = self.y
        if x1 == 0 and y1 == 0:
            print("Goc toa do")
        elif x1 == 0 and y1 != 0:
            print("Nam tren truc tung")
        elif x1 != 1 and y1 == 0:
            print("Nam tren truc hoanh")
        else:
            print("Diem tu do")
    def dist(self): 
       x1 = self.x
       y1 = self.y
       return math.sqrt(x1*x1 + y1*y1) 
    
a,b = map(int, input().split())
t = coordinate(a,b)
t.check()
print(Rounding(t.dist()))

# %%
#4
class Calc: 
    def __init__(self,x = 0,y = 0): 
        self.x = x 
        self.y = y 
    def add(self): 
        return self.x + self.y
    def substract(self): 
        return self.x - self.y
    def product(self):
        return self.x * self.y  
    def divide(self):
        return self.x/self.y
    def power(self):
        return pow(self.x, self.y)
    def mod(self): 
        return self.x % self.y
    

while True: 
    print("1.add")
    print("2.substract")
    print("3.product")
    print("4.divide")
    print("5.power")
    print("5.power")
    print("6.mod")
    print("7.set_numbers")

    c = input("Thuc hien: ")
    if c == "Yes":
        break
    elif int(c) == 1: 
        print(t.add())
    elif int(c) == 2: 
        print(t.substract())
    elif int(c) == 3: 
        print(t.product())
    elif int(c) == 4: 
        print(t.divide())
    elif int(c) == 5: 
        print(t.power())
    elif int(c) == 6: 
        print(t.mod())
    elif int(c) == 7:
        a = int(input("Nhap so a: "))
        b = int(input("Nhap so b"))
        t = Calc(a,b)

# %%
#5 later
class ShoppingCart: 
    def __init__(self): 
        self.items = []
    def add(self,name, price):
        self.items.append({"name":name, "price":price})
    def delete_items(self, name): 
        for i in range(len(self.items)): 
            if self.items[i]["name"] == name: 
                self.items.pop(i)  # lenh pop theo vi tri
                # lenh : remove(self.items[i]["name"])
                break
    def checkin(self): 
        if len(self.items) > 0: 
            print("OK")
        else: 
            print("NO OK")
    def sum(self):
        s = 0
        for i in range(len(self.items)): 
            s += self.items[i]["price"]
        return s
    def display(self):
        for i in range(len(self.items)):
            print(self.items[i]["name"])
    def wipe_out(self):
        self.items = []

while True:
    print(
    '''1. Khởi tạo với danh sách rỗng
2. Thêm vào giỏ hàng một sản phẩm mới
3. Xóa khỏi giỏ một sản phẩm nào đó 
4. Kiểm tra xem giỏ hàng có rỗng không
5. Tính tổng tiền giỏ hàng
6. Hiển thị toàn bộ sản phẩm trong giỏ
7. Xóa toàn bộ giỏ hàng

Có muốn thoát khỏi chương trình không? 
        ''')    
    
    c = input("Input: ")
    if c == "yes": 
        break
    c1 = int(c)

    if (c1 == 1): 
        t = ShoppingCart()
    elif(c1 == 2): 
        a = input()
        b = int(input())
        t.add(a,b)
    elif (c1 == 3):
        name = input()
        t.delete_items(name)
    elif (c1 == 4):
        t.checkin()
    elif (c1 == 5): 
        print(t.sum())
    elif (c1 == 6): 
        t.display()
    elif(c1 == 7):
        t.wipe_out()
# Out:
# 1. Khởi tạo với danh sách rỗng
# 2. Thêm vào giỏ hàng một sản phẩm mới
# 3. Xóa khỏi giỏ một sản phẩm nào đó
# 4. Kiểm tra xem giỏ hàng có rỗng không
# 5. Tính tổng tiền giỏ hàng
# 6. Hiển thị toàn bộ sản phẩm trong giỏ
# 7. Xóa toàn bộ giỏ hàng
#
# Có muốn thoát khỏi chương trình không?

# %%
#6
def Rounding(x):
    return (f"{x:.2f}")
class Rectangle: 
    def __init__(self, w,h): 
        self.w = w 
        self.h = h
    def area(self): return self.w * self.h
    def perimeter(self): return 2*(self.w + self.h)
    def scale(self,k):
        self.w *= k 
        self.h *= k
w,h,k = map(int, input("Input: ").split())
t = Rectangle(w,h)
t.scale(k) # truyen tham so k ( he so co dan) vao ham scaling
print(t.area())
print(t.perimeter())

# %%
#7
class Fraction: # phanso
    def __init__: 
    

a,b,op,c,d = map(int, input().split())

# %%
#8 
# initial balance số dư ban đầu 
def Rounding(x):
    return (f"{x:.2f}")
class BankAccount: 
    def __init__ (self, owner, balance): 
        self.owner = owner
        self.balance = int(balance)
    def deposit(self, a ): 
        self.balance += a
    def withdraw(self, b): 
        self.balance -= b
    def __str__(self): 
        return str(self.owner) + " "+str(self.balance) 


name, money = map(str,input().split())
t = BankAccount(name, money) 
n = int(input())
while n > 0: 
    s,k = map(str, input().split())
    if s == "DEPOSIT": 
        t.deposit(int(k))
    elif s == "WITHDRAW": 
        t.withdraw(int(k))
    n -= 1
print(t)
# Out:
# Alice 10

# %%
#9 later
def check(a):
    if a >= 8:
        return "Excellent"
    elif a <8 and a >= 6.5: 
        return "Good"
    elif a < 6.5 and a >= 5: 
        return "Average"
    else: 
        return "Poor"
class Student:
    res = 0 
    c = 0
    def __init__(self, name): 
        self.name  = name
    def add(self,sub, score): 
       self.res += score
       self.c += 1
    def avarage(self):
        return (f"{self.res/self.c:.2f}") 
name = str(input())
a = Student(name)
n =  int(input())
while n > 0: 
    s,t = map(str, input().split())
    a.add(s,int(t))
    n -= 1
print(a.name)
print(a.avarage())
print(type(a.avarage())) # chu y kieu du lieu 
print(check(float(a.avarage())))
# Out:
# Ha
# 6.50
# <class 'str'>
# Good

# %%
#10
class book: 
    def __init__(self, title, author, year): 
        self.title = title
        self.author = author
        self.year = year
class library: 
    def __init__(self):
        self.storage = []
    def add(self,book): 
        self.storage.append(book)
    def count_by_author(self,k): 
        dct = {}
        c = 0
        for i in self.storage: 
            if (i.author == k):
                c += 1 
        print(c)
    def count_by_year(self,k): 
        dct = {}
        c = 0
        for i in self.storage: 
            if i.year == k:
        
                c += 1 
        print(c)

n = int(input())
lib = library() # NOTICE this u have to create new storage
while  n > 0: 
    s = input()
    if s[0:3] == "ADD": 
        news = s[4:len(s) + 1]
        lst = list(news.split(";"))
        print(lst)
        tem = book(lst[0], lst[1], lst[2])
        lib.add(tem)
    elif s[0:5] =="COUNT" and s[5] == '':  ## check
        news = s[6:]
        lib.count_by_author(news)
    else: 
        news = s[10:]
        
        lib.count_by_year(news)
    n -= 1
# Out:
# ['T', 'A', '1999']
# ['T', 'A', '1999']
# ['T', 'A', '1999']
# 3

# %%
#11
class complex: 
    def __init__(self, *valuable):
        self.val = valuable
    def calc(self, other): 
        a,b = self.val
        c,d = other.val
        print((a*c) - (b*d), (a*d + b * c))



arr1 = list(map(int, input().split()))
arr2 = list(map(int, input().split()))

t1 = complex(*arr1)
t2 = complex(*arr2)
t1.calc(t2)
 # t1 is self t2 is other
# Out:
# -13 82

# %%
#13
import math
class Triangle: 
    def  __init__(self, edge1 , edge2, edge3): 
        self.c1 = edge1 
        self.c2 = edge2
        self.c3 = edge3
    def check(self): 
        self.c1 = a
        self.c2 = b
        self.c3 = c
        if a + b > c and a + c > b and b + c > a:
            return True
    def getArea(self): 
        self.c1 = a
        self.c2 = b
        self.c3 = c
        p = (float)(a+b+c)/2
        res = (float)(math.sqrt(p*(p-a)*(p-b)*(p-c)))
        return f"{res:.2f}"

a,b,c = map(int, input().split())
t =  Triangle(a,b,c)
if (t.check()):
    print(t.getArea())
else: 
    print("invalid")

''' 
# Code thu gọn tham khảo
import math

class Triangle:
    def __init__(self, *edges):
        self.edges = edges

    def is_valid(self):
        a, b, c = sorted(self.edges)
        return a + b > c

    def get_area(self):
        s = sum(self.edges) / 2
        a, b, c = self.edges
        area = math.sqrt(s * (s - a) * (s - b) * (s - c))
        return f"{area:.2f}"


    sides = list(map(int, input().split()))
    t = Triangle(*sides)

'''
# Out:
# 14.70
